# %%
import pandas as pd
import json

# %%
from pymongo.mongo_client import MongoClient

# %%
#url
url = "mongodb+srv://guptadaizy2495_db_user:Qphv1NNe5PveUHrE@cluster0.q2qligt.mongodb.net/?appName=Cluster0"

# %%
client = MongoClient(url)

# %%
DATABASE_NAME = "waferData"
COLLECTION_NAME = "sampleWafer"

# %%
df = pd.read_csv('notebooks\wafer_23012020_041211.csv')

# %%
df.head()
# Out:
#   Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0  Wafer-801   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0
# 1  Wafer-802   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0
# 2  Wafer-803   3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0
# 3  Wafer-804   3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0
# 4  Wafer-805   3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0   97.5822    0.1242    1.5300  ...         NaN      0.5004      0.0120
# 1   96.7700    0.1230    1.3953  ...         NaN      0.4994      0.0115
# 2  101.8644    0.1220    1.3896  ...         NaN      0.4987      0.0118
# 3  101.8644    0.1220    1.4108  ...         NaN      0.4934      0.0123
# 4  104.8856    0.1234    1.5094  ...         NaN      0.4987      0.0145
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 592 entries, Unnamed: 0 to Good/Bad
# dtypes: float64(494), int64(97), object(1)
# memory usage: 462.6+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Sensor-1      1
# Sensor-2      0
# Sensor-3      3
# Sensor-4      3
#              ..
# Sensor-587    0
# Sensor-588    0
# Sensor-589    0
# Sensor-590    0
# Good/Bad      0
# Length: 592, dtype: int64

# %%
# df[df.isnull().sum()]
df.loc[:,df.isnull().sum()>0]
# Out:
#     Sensor-1   Sensor-3   Sensor-4  Sensor-5  Sensor-6  Sensor-7  Sensor-8  \
# 0    2968.33  2216.7333  1748.0885    1.1127     100.0   97.5822    0.1242
# 1    2961.04  2170.0666  1364.5157    1.5447     100.0   96.7700    0.1230
# 2    3072.03  2205.7445  1363.1048    1.0518     100.0  101.8644    0.1220
# 3    3021.83  2205.7445  1363.1048    1.0518     100.0  101.8644    0.1220
# 4    3006.95  2189.8111  1084.6502    1.1993     100.0  104.8856    0.1234
# ..       ...        ...        ...       ...       ...       ...       ...
# 95   3013.66  2185.2111  1141.6306    0.8447     100.0  100.5978    0.1217
# 96   2982.87  2315.2667  2360.1325    1.1259     100.0   90.1144    0.1160
# 97   3084.82  2171.5000  1028.4440    0.7899     100.0  101.5122    0.1224
# 98   2955.87        NaN        NaN       NaN       NaN       NaN       NaN
# 99   2914.86  2210.2778  2120.5760    1.0700     100.0   95.1089    0.1230
#
# ...

# %%
df.columns[df.isnull().sum() > 0]
# Out:
# Index(['Sensor-1', 'Sensor-3', 'Sensor-4', 'Sensor-5', 'Sensor-6', 'Sensor-7',
#        'Sensor-8', 'Sensor-41', 'Sensor-42', 'Sensor-54',
#        ...
#        'Sensor-565', 'Sensor-566', 'Sensor-567', 'Sensor-568', 'Sensor-569',
#        'Sensor-570', 'Sensor-579', 'Sensor-580', 'Sensor-581', 'Sensor-582'],
#       dtype='object', length=167)

# %%
null_columns = df.isnull().sum()
null_columns = null_columns[null_columns > 0]
print(null_columns)
# Out:
# Sensor-1       1
# Sensor-3       3
# Sensor-4       3
# Sensor-5       3
# Sensor-6       3
#               ..
# Sensor-570     3
# Sensor-579    66
# Sensor-580    66
# Sensor-581    66
# Sensor-582    66
# Length: 167, dtype: int64

# %%
df.isnull().mean()
# Out:
# Unnamed: 0    0.00
# Sensor-1      0.01
# Sensor-2      0.00
# Sensor-3      0.03
# Sensor-4      0.03
#               ...
# Sensor-587    0.00
# Sensor-588    0.00
# Sensor-589    0.00
# Sensor-590    0.00
# Good/Bad      0.00
# Length: 592, dtype: float64

# %%
threshold = 0.7
null_percent = df.isnull().mean()
null_cols = null_percent[null_percent>threshold]
print(null_cols)
# Out:
# Sensor-158    0.91
# Sensor-159    0.91
# Sensor-293    0.91
# Sensor-294    0.91
# dtype: float64

# %%
row_null_percentage = df.isnull().mean(axis=1)
high_null_rows = df[row_null_percentage > 0.7]
print(high_null_rows)
# Out:
# Empty DataFrame
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4',
#        'Sensor-5', 'Sensor-6', 'Sensor-7', 'Sensor-8', 'Sensor-9',
#        ...
#        'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585', 'Sensor-586',
#        'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590', 'Good/Bad'],
#       dtype='object', length=592)

# %%
df['Good/Bad'].value_counts(normalize=True)*100
# Out:
# Good/Bad
# -1    94.0
#  1     6.0
# Name: proportion, dtype: float64

# %% [markdown]
# imbalance dataset

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.columns
# Out:
# Index(['Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4', 'Sensor-5', 'Sensor-6',
#        'Sensor-7', 'Sensor-8', 'Sensor-9', 'Sensor-10',
#        ...
#        'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585', 'Sensor-586',
#        'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590', 'Good/Bad'],
#       dtype='object', length=591)

# %%
json_record = list(json.loads(df.T.to_json()).values())

# %%
client[DATABASE_NAME][COLLECTION_NAME].insert_many(json_record)
